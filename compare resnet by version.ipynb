  0.67675],
 'val': [0.39233038348082594,
  0.46509341199606685,
  0.40216322517207476,
  0.4886922320550639,
  0.45427728613569324,
  0.511307767944936,
  0.5398230088495575,
  0.5634218289085545,
  0.5771878072763028,
  0.504424778761062,
  0.4611602753195674,
  0.5526057030481809,
  0.5663716814159292,
  0.49655850540806296,
  0.40707964601769914,
  0.40904621435594885,
  0.46607669616519176,
  0.4995083579154376,
  0.5250737463126843,
  0.5585054080629301]}

duration_time = 9.4524


resnet101_dict = {
    'loss_hist' : loss_hist,
    'metric_hist' : metric_hist,
    'time' : duration_time
}

# %% [markdown]
# Resent152 20회 학습 데이터

# %%
loss_hist = {'train': [2.030527069091797,
  1.5321538190841675,
  1.3996361031532287,
  1.281360770702362,
  1.2221389598846435,
  1.1772285780906677,
  1.1791375064849854,
  1.1727684922218322,
  1.1918533568382264,
  1.1317541670799256,
  1.3783771696090699,
  1.2817680673599243,
  1.1693316974639894,
  1.285473415851593,
  1.199988302707672,
  1.2663175320625306,
  1.1432334475517274,
  0.9217473864555359,
  0.8272135455608368,
  0.8297446532249451],
 'val': [2.870946559699705,
  4.459253106731463,
  1.4853850076801072,
  4.481051731015846,
  1.22616653104799,
  1.2000365168178562,
  3.3960287793664925,
  1.4915379962152202,
  3.20903929051162,
  1.7440455670202024,
  2.343779996198656,
  1.3294410555529148,
  1.246036897132296,
  1.5847856227158328,
  1.207911741768716,
  3.18901581515722,
  1.3831484840565609,
  1.334627204002298,
  6.463260367439442,
  2.2182396051337467]}

metric_hist ={'train': [0.31175,
  0.444,
  0.48825,
  0.5345,
  0.551,
  0.579,
  0.558,
  0.56625,
  0.55475,
  0.59,
  0.48225,
  0.5235,
  0.57,
  0.52225,
  0.566,
  0.53425,
  0.5815,
  0.6615,
  0.698,
  0.7025],
 'val': [0.40216322517207476,
  0.43756145526057033,
  0.4473942969518191,
  0.464110127826942,
  0.52015732546706,
  0.5349065880039331,
  0.5329400196656834,
  0.4857423795476893,
  0.5555555555555556,
  0.5732546705998034,
  0.46607669616519176,
  0.5486725663716814,
  0.5378564405113078,
  0.5231071779744346,
  0.5614552605703048,
  0.5447394296951819,
  0.5653883972468043,
  0.5880039331366765,
  0.5939036381514258,
  0.5830875122910522]}

duration_time = 11.3707


resnet152_dict = {
    'loss_hist' : loss_hist,
    'metric_hist' : metric_hist,
    'time' : duration_time
}

# %% [markdown]
# 결과 확인

# %%
resnet18_dict['loss_hist']['train']    #train data의 loss
resnet18_dict['loss_hist']['val']      #valid data의 loss
resnet18_dict['metric_hist']['train']  #train data의 정확도
resnet18_dict['metric_hist']['val']    #valid data의 정확도


resnet34_dict
resnet50_dict
resnet101_dict
resnet152_dict
# Out:
# {'loss_hist': {'train': [2.030527069091797,
#    1.5321538190841675,
#    1.3996361031532287,
#    1.281360770702362,
#    1.2221389598846435,
#    1.1772285780906677,
#    1.1791375064849854,
#    1.1727684922218322,
#    1.1918533568382264,
#    1.1317541670799256,
#    1.3783771696090699,
#    1.2817680673599243,
#    1.1693316974639894,
#    1.285473415851593,
#    1.199988302707672,
#    1.2663175320625306,
#    1.1432334475517274,
#    0.9217473864555359,
#    0.8272135455608368,
#    0.8297446532249451],
#   'val': [2.870946559699705,
#    4.459253106731463,
#    1.4853850076801072,
#    4.481051731015846,
#    1.22616653104799,
#    1.2000365168178562,
#    3.3960287793664925,
#    1.4915379962152202,
#    3.20903929051162,
#    1.7440455670202024,
#    2.343779996198656,
#    1.3294410555529148,
#    1.246036897132296,
#    1.5847856227158328,
#    1.207911741768716,
#    3.18901581515722,
#    1.3831484840565609,
#    1.334627204002298,
#    6.463260367439442,
# ...

# %%
import os
import torch
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, random_split, DataLoader
from PIL import Image
import torchvision.models as models
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
from sklearn.metrics import f1_score
import torch.nn.functional as F
import torch.nn as nn
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder

# %%
#train loss, val loss 그래프와 정확도 그래프를 확인하겠습니다.

'''resnet18'''
# Train-Validation Progress
num_epochs=20

# plot loss progress
plt.title("resnet18 Train-Val Loss")
plt.plot(range(1,num_epochs+1),resnet18_dict["loss_hist"]["train"],label="train")
plt.plot(range(1,num_epochs+1),resnet18_dict["loss_hist"]["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("resnet18 Train-Val Accuracy")
plt.plot(range(1,num_epochs+1),resnet18_dict["metric_hist"]["train"],label="train")
plt.plot(range(1,num_epochs+1),resnet18_dict["metric_hist"]["val"],label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
'''resnet34'''
# Train-Validation Progress
num_epochs=20

# plot loss progress
plt.title("resnet34 Train-Val Loss")
plt.plot(range(1,num_epochs+1),resnet34_dict["loss_hist"]["train"],label="train")
plt.plot(range(1,num_epochs+1),resnet34_dict["loss_hist"]["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("resnet34 Train-Val Accuracy")
plt.plot(range(1,num_epochs+1),resnet34_dict["metric_hist"]["train"],label="train")
plt.plot(range(1,num_epochs+1),resnet34_dict["metric_hist"]["val"],label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
'''resnet50'''
# Train-Validation Progress
num_epochs=20

# plot loss progress
plt.title("resnet50 Train-Val Loss")
plt.plot(range(1,num_epochs+1),resnet50_dict["loss_hist"]["train"],label="train")
plt.plot(range(1,num_epochs+1),resnet50_dict["loss_hist"]["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("resnet50 Train-Val Accuracy")
plt.plot(range(1,num_epochs+1),resnet50_dict["metric_hist"]["train"],label="train")
plt.plot(range(1,num_epochs+1),resnet50_dict["metric_hist"]["val"],label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
'''resnet101'''
# Train-Validation Progress
num_epochs=20

# plot loss progress
plt.title("resnet101 Train-Val Loss")
plt.plot(range(1,num_epochs+1),resnet101_dict["loss_hist"]["train"],label="train")
plt.plot(range(1,num_epochs+1),resnet101_dict["loss_hist"]["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("resnet101 Train-Val Accuracy")
plt.plot(range(1,num_epochs+1),resnet101_dict["metric_hist"]["train"],label="train")
plt.plot(range(1,num_epochs+1),resnet101_dict["metric_hist"]["val"],label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
'''resnet152'''
# Train-Validation Progress
num_epochs=20

# plot loss progress
plt.title("resnet152 Train-Val Loss")
plt.plot(range(1,num_epochs+1),resnet152_dict["loss_hist"]["train"],label="train")
plt.plot(range(1,num_epochs+1),resnet152_dict["loss_hist"]["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("resnet152 Train-Val Accuracy")
plt.plot(range(1,num_epochs+1),resnet152_dict["metric_hist"]["train"],label="train")
plt.plot(range(1,num_epochs+1),resnet152_dict["metric_hist"]["val"],label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
'''버전별 Train 데이터의 Loss& Accuracy'''
# Train-Validation Progress
num_epochs=20

# plot loss progress
plt.title("Loss of Train data by Resnet version")
plt.plot(range(1,num_epochs+1),resnet152_dict["loss_hist"]["train"],label="resnet152")
plt.plot(range(1,num_epochs+1),resnet101_dict["loss_hist"]["train"],label="resnet101")
plt.plot(range(1,num_epochs+1),resnet50_dict["loss_hist"]["train"],label="resnet50")
plt.plot(range(1,num_epochs+1),resnet34_dict["loss_hist"]["train"],label="resnet34")
plt.plot(range(1,num_epochs+1),resnet18_dict["loss_hist"]["train"],label="resnet18")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("Accuracy of Train data by Resnet version")
plt.plot(range(1,num_epochs+1),resnet152_dict["metric_hist"]["train"],label="resnet152")
plt.plot(range(1,num_epochs+1),resnet101_dict["metric_hist"]["train"],label="resnet101")
plt.plot(range(1,num_epochs+1),resnet50_dict["metric_hist"]["train"],label="resnet50")
plt.plot(range(1,num_epochs+1),resnet34_dict["metric_hist"]["train"],label="resnet34")
plt.plot(range(1,num_epochs+1),resnet18_dict["metric_hist"]["train"],label="resnet18")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
'''버전별 Val 데이터의 Loss& Accuracy'''
# Train-Validation Progress
num_epochs=20

# plot loss progress
plt.title("Loss of Val data by Resnet version")
plt.plot(range(1,num_epochs+1),resnet152_dict["loss_hist"]["val"],label="resnet152")
plt.plot(range(1,num_epochs+1),resnet101_dict["loss_hist"]["val"],label="resnet101")
plt.plot(range(1,num_epochs+1),resnet50_dict["loss_hist"]["val"],label="resnet50")
plt.plot(range(1,num_epochs+1),resnet34_dict["loss_hist"]["val"],label="resnet34")
plt.plot(range(1,num_epochs+1),resnet18_dict["loss_hist"]["val"],label="resnet18")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("Accuracy of Val data by Resnet version")
plt.plot(range(1,num_epochs+1),resnet152_dict["metric_hist"]["val"],label="resnet152")
plt.plot(range(1,num_epochs+1),resnet101_dict["metric_hist"]["val"],label="resnet101")
plt.plot(range(1,num_epochs+1),resnet50_dict["metric_hist"]["val"],label="resnet50")
plt.plot(range(1,num_epochs+1),resnet34_dict["metric_hist"]["val"],label="resnet34")
plt.plot(range(1,num_epochs+1),resnet18_dict["metric_hist"]["val"],label="resnet18")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()
